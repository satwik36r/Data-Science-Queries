# %%
import collections
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize

# %%
# Reads file and extracts all the reviews/text content

file = open("finefoods.txt", "r", encoding = "ISO-8859-1")
text= file.readlines()
reviews = [line.split('review/text: ')[1] for line in text if "review/text:" in line]
len(reviews)
# Out:
# 568454

# %%
# Get all stopwords

data = open("LongStop.txt", "r", encoding = "ISO-8859-1")
data = data.readlines()
stop_words = []
for line in data:
  for word in line.split():
    stop_words.append(word.lower())

# %%
# Get all the words present in review/text

words = []
for line in reviews:
  for word in line.split():
    words.append(word.lower())

# %%
# Get distinct words

L = list(set(words))
print(len(L))
# Out:
# 506062

# %%
# Cleaned Set - Removed StopWords, Punctuations

W = [word for word in L if (word not in stop_words) and word.isalpha()]
print(len(W))
# Out:
# 86738

# %%
# Finds the count of all the words before any alterations like performing set to remove duplicates

countofwords = collections.Counter(words)
len(countofwords)
# Out:
# 506062

# %%
# Getting the words present in the clean set only

for word in list(countofwords):
  if word not in W:
    del countofwords[word]

len(countofwords)
# Out:
# 86738

# %%
# Top 500 words:

data = countofwords.most_common(500)
data
# Out:
# [('good', 147853),
#  ('great', 130957),
#  ('taste', 127457),
#  ('will', 125047),
#  ('love', 121572),
#  ('coffee', 115167),
#  ('product', 101020),
#  ('tea', 95106),
#  ('flavor', 93135),
#  ('food', 86883),
#  ('buy', 71498),
#  ('find', 69122),
#  ('best', 63498),
#  ('eat', 59276),
#  ('dog', 58456),
#  ('time', 54812),
#  ('better', 54727),
#  ('amazon', 52356),
#  ('price', 50586),
#  ('bought', 48573),
#  ('chocolate', 47238),
#  ('tastes', 42856),
#  ('cup', 41910),
#  ('drink', 41459),
#  ('bag', 40613),
#  ('well', 40252),
#  ('bit', 40040),
#  ('water', 39156),
#  ('recommend', 38588),
#  ('order', 38501),
#  ('nice', 36066),
#  ('loves', 35679),
#  ('box', 35450),
#  ('sweet', 35136),
#  ('sugar', 34633),
#  ('add', 34005),
#  ('hot', 32434),
#  ('cat', 32001),
#  ('lot', 31898),
#  ('ordered', 30685),
#  ('favorite', 30010),
#  ('small', 29825),
#  ('mix', 29435),
#  ('eating', 29250),
#  ('dogs', 29091),
#  ('free', 28627),
#  ('definitely', 28593),
#  ('store', 28283),
#  ('buying', 28160),
#  ('brand', 27534),
#  ('easy', 27136),
#  ('thought', 27091),
#  ('pretty', 26950),
#  ('green', 26868),
#  ('local', 26858),
#  ('quality', 26820),
#  ('hard', 26743),
#  ('regular', 26641),
#  ('organic', 26341),
#  ('healthy', 25865),
#  ('perfect', 25839),
#  ('long', 25398),
#  ('going', 25252),
#  ('high', 25102),
#  ('day', 24897),
#  ('flavors', 24601),
#  ('big', 24553),
#  ('enjoy', 24095),
#  ('years', 24055),
#  ('strong', 23929),
#  ('stuff', 23093),
#  ('feel', 23062),
#  ('chips', 22918),
#  ('happy', 22915),
#  ('treats', 22667),
#  ('bad', 22579),
#  ('real', 22443),
#  ('milk', 22303),
#  ('people', 22212),
#  ('worth', 22054),
#  ('purchased', 22004),
#  ('ingredients', 21981),
#  ('highly', 21693),
#  ('bags', 21667),
#  ('fresh', 21554),
#  ('cats', 21550),
#  ('chicken', 21418),
#  ('natural', 21269),
#  ('thing', 21253),
#  ('size', 20886),
#  ('snack', 20514),
#  ('products', 20178),
#  ('amount', 19990),
#  ('work', 19986),
#  ('grocery', 19790),
#  ('delicious', 19753),
#  ('tasted', 19361),
#  ('salt', 19281),
#  ('loved', 19211),
#  ('dry', 19198),
#  ('cookies', 19067),
#  ('package', 19039),
#  ('oil', 18878),
#  ('purchase', 18870),
#  ('low', 18778),
#  ('coconut', 18775),
#  ('half', 18718),
#  ('treat', 18671),
#  ('dark', 18614),
#  ('received', 18268),
#  ('kind', 18252),
#  ('full', 17689),
#  ('three', 17480),
#  ('smell', 17383),
#  ('butter', 17182),
#  ('excellent', 17163),
#  ('making', 17087),
#  ('year', 16907),
#  ('wonderful', 16841),
#  ('peanut', 16807),
#  ('pack', 16686),
#  ('tasting', 16646),
#  ('vanilla', 16604),
#  ('drinking', 16441),
#  ('sauce', 16360),
#  ('shipping', 16206),
#  ('black', 16078),
#  ('bars', 16010),
#  ('fruit', 15995),
#  ('rice', 15883),
#  ('diet', 15879),
#  ('family', 15815),
#  ('large', 15778),
#  ('flavored', 15725),
#  ('things', 15667),
#  ('foods', 15639),
#  ('decided', 15610),
#  ('texture', 15383),
#  ('protein', 15355),
#  ('absolutely', 15174),
#  ('started', 15131),
#  ('arrived', 15078),
#  ('gluten', 15073),
#  ('expensive', 14991),
#  ('extra', 14951),
#  ('tasty', 14896),
#  ('health', 14808),
#  ('couple', 14798),
#  ('bottle', 14624),
#  ('prefer', 14415),
#  ('husband', 14326),
#  ('brands', 13849),
#  ('blend', 13836),
#  ('problem', 13829),
#  ('calories', 13753),
#  ('light', 13689),
#  ('wanted', 13605),
#  ('candy', 13596),
#  ('kids', 13554),
#  ('top', 13529),
#  ('company', 13524),
#  ('reviews', 13374),
#  ('case', 13364),
#  ('fat', 13207),
#  ('morning', 13168),
#  ('read', 13112),
#  ('months', 13081),
#  ('variety', 13012),
#  ('times', 12872),
#  ('cereal', 12719),
#  ('corn', 12608),
#  ('white', 12504),
#  ('works', 12492),
#  ('stores', 12454),
#  ('review', 12407),
#  ('boxes', 12357),
#  ('ordering', 12280),
#  ('days', 12280),
#  ('save', 12240),
#  ('open', 12230),
#  ('item', 12147),
#  ('glad', 11984),
#  ('cheaper', 11899),
#  ('bar', 11875),
#  ('help', 11871),
#  ('energy', 11852),
#  ('baby', 11840),
#  ('red', 11742),
#  ('cups', 11625),
#  ('longer', 11218),
#  ('fact', 11212),
#  ('cost', 11154),
#  ('likes', 11109),
#  ('beans', 10943),
#  ('honey', 10941),
#  ('cheese', 10882),
#  ('breakfast', 10715),
#  ('popcorn', 10699),
#  ('packaging', 10654),
#  ('cans', 10553),
#  ('bitter', 10514),
#  ('mixed', 10439),
#  ('second', 10417),
#  ('feed', 10339),
#  ('cream', 10296),
#  ('canned', 10272),
#  ('smooth', 10176),
#  ('keurig', 10153),
#  ('money', 10090),
#  ('fan', 10088),
#  ('plastic', 10039),
#  ('rich', 9992),
#  ('quick', 9968),
#  ('pieces', 9847),
#  ('dried', 9802),
#  ('type', 9782),
#  ('enjoyed', 9770),
#  ('potato', 9754),
#  ('super', 9746),
#  ('stars', 9717),
#  ('bold', 9656),
#  ('opened', 9651),
#  ('soft', 9630),
#  ('fine', 9516),
#  ('cut', 9464),
#  ('teas', 9447),
#  ('french', 9423),
#  ('deal', 9422),
#  ('roast', 9418),
#  ('start', 9362),
#  ('son', 9354),
#  ('pet', 9354),
#  ('recommended', 9326),
#  ('bread', 9321),
#  ('smaller', 9290),
#  ('disappointed', 9218),
#  ('exactly', 9211),
#  ('house', 9207),
#  ('month', 9201),
#  ('weight', 9199),
#  ('artificial', 9119),
#  ('meat', 9098),
#  ('beef', 9085),
#  ('single', 9063),
#  ('ice', 9059),
#  ('care', 9012),
#  ('ginger', 9009),
#  ('cookie', 8983),
#  ('powder', 8982),
#  ('brown', 8963),
#  ('guess', 8954),
#  ('oz', 8949),
#  ('left', 8927),
#  ('serving', 8811),
#  ('juice', 8774),
#  ('simply', 8767),
#  ('pay', 8762),
#  ('hair', 8610),
#  ('compared', 8586),
#  ('spicy', 8538),
#  ('ate', 8492),
#  ('fast', 8487),
#  ('blue', 8474),
#  ('brew', 8474),
#  ('starbucks', 8393),
#  ('side', 8386),
#  ('minutes', 8359),
#  ('cinnamon', 8339),
#  ('noticed', 8331),
#  ('looked', 8320),
#  ('wheat', 8306),
#  ('smells', 8285),
#  ('gift', 8283),
#  ('syrup', 8251),
#  ('wife', 8202),
#  ('soup', 8198),
#  ('daughter', 8082),
#  ('huge', 8071),
#  ('hope', 8070),
#  ('plain', 8022),
#  ('easily', 8017),
#  ('friends', 8000),
#  ('adding', 7986),
#  ('feeding', 7943),
#  ('reason', 7925),
#  ('cold', 7916),
#  ('chew', 7899),
#  ('leave', 7882),
#  ('vet', 7865),
#  ('difference', 7864),
#  ('place', 7851),
#  ('meal', 7836),
#  ('soy', 7822),
#  ('stick', 7761),
#  ('subscribe', 7740),
#  ('lemon', 7714),
#  ('pasta', 7696),
#  ('surprised', 7674),
#  ('lots', 7662),
#  ('continue', 7661),
#  ('pleased', 7634),
#  ('daily', 7622),
#  ('takes', 7607),
#  ('special', 7590),
#  ('week', 7540),
#  ('larger', 7531),
#  ('ingredient', 7521),
#  ('ground', 7508),
#  ('close', 7504),
#  ('extremely', 7499),
#  ('jerky', 7482),
#  ('alternative', 7469),
#  ('version', 7468),
#  ('picky', 7448),
#  ('original', 7448),
#  ('helps', 7422),
#  ('spice', 7411),
#  ('cook', 7281),
#  ('completely', 7249),
#  ('live', 7241),
#  ('change', 7233),
#  ('crunchy', 7231),
#  ('ago', 7188),
#  ('weeks', 7161),
#  ('finally', 7120),
#  ('mouth', 7098),
#  ('instant', 7087),
#  ('problems', 7056),
#  ('iced', 7054),
#  ('container', 7044),
#  ('apple', 7023),
#  ('told', 6995),
#  ('entire', 6988),
#  ('orange', 6930),
#  ('cooking', 6927),
#  ('cocoa', 6919),
#  ('medium', 6866),
#  ('teeth', 6824),
#  ('decaf', 6796),
#  ('friend', 6778),
#  ('clean', 6774),
#  ('based', 6761),
#  ('recipe', 6758),
#  ('formula', 6750),
#  ('shipped', 6706),
#  ('inside', 6703),
#  ('bowl', 6701),
#  ('excited', 6701),
#  ('nuts', 6692),
#  ('mild', 6681),
#  ('rest', 6669),
#  ('online', 6640),
#  ('amazing', 6637),
#  ('oatmeal', 6624),
#  ('raw', 6589),
#  ('carry', 6586),
#  ('chip', 6579),
#  ('expect', 6500),
#  ('sold', 6482),
#  ('star', 6473),
#  ('grain', 6469),
#  ('called', 6468),
#  ('needed', 6460),
#  ('body', 6448),
#  ('leaves', 6447),
#  ('pods', 6439),
#  ('list', 6420),
#  ('idea', 6404),
#  ('heat', 6348),
#  ('packs', 6347),
#  ('eats', 6346),
#  ('aroma', 6295),
#  ('olive', 6279),
#  ('reading', 6274),
#  ('purchasing', 6271),
#  ('hint', 6212),
#  ('espresso', 6197),
#  ('drinks', 6184),
#  ('packaged', 6179),
#  ('glass', 6154),
#  ('grams', 6151),
#  ('ounce', 6112),
#  ('wait', 6100),
#  ('snacks', 6093),
#  ('jar', 6091),
#  ('bottles', 6086),
#  ('fiber', 6073),
#  ('machine', 6039),
#  ('stomach', 6024),
#  ('salty', 6018),
#  ('difficult', 5949),
#  ('almond', 5938),
#  ('stopped', 5917),
#  ('sodium', 5916),
#  ('crackers', 5908),
#  ('caffeine', 5899),
#  ('skin', 5870),
#  ('choice', 5861),
#  ('break', 5856),
#  ('wellness', 5851),
#  ('discovered', 5848),
#  ('normal', 5844),
#  ('calorie', 5841),
#  ('coffees', 5830),
#  ('packages', 5828),
#  ('color', 5825),
#  ('life', 5823),
#  ('bulk', 5807),
#  ('chai', 5798),
#  ('cake', 5773),
#  ('healthier', 5768),
#  ('bottom', 5758),
#  ('felt', 5745),
#  ('eaten', 5741),
#  ('totally', 5726),
#  ('throw', 5710),
#  ('mine', 5709),
#  ('waste', 5702),
#  ('stay', 5692),
#  ('granola', 5686),
#  ('night', 5674),
#  ('pound', 5665),
#  ('delivered', 5661),
#  ('pepper', 5639),
#  ('fish', 5634),
#  ('lower', 5634),
#  ('mountain', 5625),
#  ('cheap', 5624),
#  ('mind', 5624),
#  ('gum', 5611),
#  ('hours', 5592),
#  ('experience', 5578),
#  ('finding', 5565),
#  ('almonds', 5559),
#  ('delivery', 5500),
#  ('bite', 5494),
#  ('service', 5493),
#  ('convenient', 5455),
#  ('pure', 5455),
#  ('packets', 5450),
#  ('pot', 5431),
#  ('decent', 5414),
#  ('loose', 5406),
#  ('noodles', 5402),
#  ('vitamin', 5382),
#  ('market', 5381),
#  ('soda', 5371),
#  ('easier', 5370),
#  ('tiny', 5357),
#  ('puppy', 5333),
#  ('supposed', 5324),
#  ('pop', 5312),
#  ('worked', 5304),
#  ('call', 5303),
#  ('thinking', 5298),
#  ('packet', 5292),
#  ('baked', 5276),
#  ('liquid', 5276),
#  ('true', 5274),
#  ('turned', 5265),
#  ('packed', 5263),
#  ('wrong', 5252),
#  ('items', 5239),
#  ('hand', 5239),
#  ('label', 5232),
#  ('bean', 5228),
#  ('flour', 5198),
#  ('seeds', 5185),
#  ('flavorful', 5170),
#  ('set', 5169),
#  ('stock', 5135),
#  ('point', 5118),
#  ('customer', 5085),
#  ('sell', 5058),
#  ('bring', 5055),
#  ('higher', 5034),
#  ('pick', 5015),
#  ('brewed', 5015),
#  ('course', 4989),
#  ('hoping', 4954),
#  ('serve', 4954),
#  ('mint', 4950),
#  ('blood', 4907),
#  ('check', 4893),
#  ('wet', 4882),
#  ('thick', 4870),
#  ('sort', 4870),
#  ('double', 4856),
#  ('notice', 4837),
#  ('weak', 4830),
#  ('remember', 4829),
#  ('feeling', 4822),
#  ('individual', 4820),
#  ('plan', 4812),
#  ('including', 4798),
#  ('stash', 4790),
#  ('piece', 4790),
#  ('addition', 4775),
#  ('fairly', 4773),
#  ('nut', 4766)]

# %%
# Vectorize

top_500_words = [ele[0] for ele in list(data)]
vectorizing = CountVectorizer(vocabulary = top_500_words)
vec = vectorizing.fit_transform(reviews)

# %%
top_500_words
# Out:
# ['good',
#  'great',
#  'taste',
#  'will',
#  'love',
#  'coffee',
#  'product',
#  'tea',
#  'flavor',
#  'food',
#  'buy',
#  'find',
#  'best',
#  'eat',
#  'dog',
#  'time',
#  'better',
#  'amazon',
#  'price',
#  'bought',
#  'chocolate',
#  'tastes',
#  'cup',
#  'drink',
#  'bag',
#  'well',
#  'bit',
#  'water',
#  'recommend',
#  'order',
#  'nice',
#  'loves',
#  'box',
#  'sweet',
#  'sugar',
#  'add',
#  'hot',
#  'cat',
#  'lot',
#  'ordered',
#  'favorite',
#  'small',
#  'mix',
#  'eating',
#  'dogs',
#  'free',
#  'definitely',
#  'store',
#  'buying',
#  'brand',
#  'easy',
#  'thought',
#  'pretty',
#  'green',
#  'local',
#  'quality',
#  'hard',
#  'regular',
#  'organic',
#  'healthy',
#  'perfect',
#  'long',
#  'going',
#  'high',
#  'day',
#  'flavors',
#  'big',
#  'enjoy',
#  'years',
#  'strong',
#  'stuff',
#  'feel',
#  'chips',
#  'happy',
#  'treats',
#  'bad',
#  'real',
#  'milk',
#  'people',
#  'worth',
#  'purchased',
#  'ingredients',
#  'highly',
#  'bags',
#  'fresh',
#  'cats',
#  'chicken',
#  'natural',
#  'thing',
#  'size',
#  'snack',
#  'products',
#  'amount',
#  'work',
#  'grocery',
#  'delicious',
#  'tasted',
#  'salt',
#  'loved',
#  'dry',
#  'cookies',
#  'package',
#  'oil',
#  'purchase',
#  'low',
#  'coconut',
#  'half',
#  'treat',
#  'dark',
#  'received',
#  'kind',
#  'full',
#  'three',
#  'smell',
#  'butter',
#  'excellent',
#  'making',
#  'year',
#  'wonderful',
#  'peanut',
#  'pack',
#  'tasting',
#  'vanilla',
#  'drinking',
#  'sauce',
#  'shipping',
#  'black',
#  'bars',
#  'fruit',
#  'rice',
#  'diet',
#  'family',
#  'large',
#  'flavored',
#  'things',
#  'foods',
#  'decided',
#  'texture',
#  'protein',
#  'absolutely',
#  'started',
#  'arrived',
#  'gluten',
#  'expensive',
#  'extra',
#  'tasty',
#  'health',
#  'couple',
#  'bottle',
#  'prefer',
#  'husband',
#  'brands',
#  'blend',
#  'problem',
#  'calories',
#  'light',
#  'wanted',
#  'candy',
#  'kids',
#  'top',
#  'company',
#  'reviews',
#  'case',
#  'fat',
#  'morning',
#  'read',
#  'months',
#  'variety',
#  'times',
#  'cereal',
#  'corn',
#  'white',
#  'works',
#  'stores',
#  'review',
#  'boxes',
#  'ordering',
#  'days',
#  'save',
#  'open',
#  'item',
#  'glad',
#  'cheaper',
#  'bar',
#  'help',
#  'energy',
#  'baby',
#  'red',
#  'cups',
#  'longer',
#  'fact',
#  'cost',
#  'likes',
#  'beans',
#  'honey',
#  'cheese',
#  'breakfast',
#  'popcorn',
#  'packaging',
#  'cans',
#  'bitter',
#  'mixed',
#  'second',
#  'feed',
#  'cream',
#  'canned',
#  'smooth',
#  'keurig',
#  'money',
#  'fan',
#  'plastic',
#  'rich',
#  'quick',
#  'pieces',
#  'dried',
#  'type',
#  'enjoyed',
#  'potato',
#  'super',
#  'stars',
#  'bold',
#  'opened',
#  'soft',
#  'fine',
#  'cut',
#  'teas',
#  'french',
#  'deal',
#  'roast',
#  'start',
#  'son',
#  'pet',
#  'recommended',
#  'bread',
#  'smaller',
#  'disappointed',
#  'exactly',
#  'house',
#  'month',
#  'weight',
#  'artificial',
#  'meat',
#  'beef',
#  'single',
#  'ice',
#  'care',
#  'ginger',
#  'cookie',
#  'powder',
#  'brown',
#  'guess',
#  'oz',
#  'left',
#  'serving',
#  'juice',
#  'simply',
#  'pay',
#  'hair',
#  'compared',
#  'spicy',
#  'ate',
#  'fast',
#  'blue',
#  'brew',
#  'starbucks',
#  'side',
#  'minutes',
#  'cinnamon',
#  'noticed',
#  'looked',
#  'wheat',
#  'smells',
#  'gift',
#  'syrup',
#  'wife',
#  'soup',
#  'daughter',
#  'huge',
#  'hope',
#  'plain',
#  'easily',
#  'friends',
#  'adding',
#  'feeding',
#  'reason',
#  'cold',
#  'chew',
#  'leave',
#  'vet',
#  'difference',
#  'place',
#  'meal',
#  'soy',
#  'stick',
#  'subscribe',
#  'lemon',
#  'pasta',
#  'surprised',
#  'lots',
#  'continue',
#  'pleased',
#  'daily',
#  'takes',
#  'special',
#  'week',
#  'larger',
#  'ingredient',
#  'ground',
#  'close',
#  'extremely',
#  'jerky',
#  'alternative',
#  'version',
#  'picky',
#  'original',
#  'helps',
#  'spice',
#  'cook',
#  'completely',
#  'live',
#  'change',
#  'crunchy',
#  'ago',
#  'weeks',
#  'finally',
#  'mouth',
#  'instant',
#  'problems',
#  'iced',
#  'container',
#  'apple',
#  'told',
#  'entire',
#  'orange',
#  'cooking',
#  'cocoa',
#  'medium',
#  'teeth',
#  'decaf',
#  'friend',
#  'clean',
#  'based',
#  'recipe',
#  'formula',
#  'shipped',
#  'inside',
#  'bowl',
#  'excited',
#  'nuts',
#  'mild',
#  'rest',
#  'online',
#  'amazing',
#  'oatmeal',
#  'raw',
#  'carry',
#  'chip',
#  'expect',
#  'sold',
#  'star',
#  'grain',
#  'called',
#  'needed',
#  'body',
#  'leaves',
#  'pods',
#  'list',
#  'idea',
#  'heat',
#  'packs',
#  'eats',
#  'aroma',
#  'olive',
#  'reading',
#  'purchasing',
#  'hint',
#  'espresso',
#  'drinks',
#  'packaged',
#  'glass',
#  'grams',
#  'ounce',
#  'wait',
#  'snacks',
#  'jar',
#  'bottles',
#  'fiber',
#  'machine',
#  'stomach',
#  'salty',
#  'difficult',
#  'almond',
#  'stopped',
#  'sodium',
#  'crackers',
#  'caffeine',
#  'skin',
#  'choice',
#  'break',
#  'wellness',
#  'discovered',
#  'normal',
#  'calorie',
#  'coffees',
#  'packages',
#  'color',
#  'life',
#  'bulk',
#  'chai',
#  'cake',
#  'healthier',
#  'bottom',
#  'felt',
#  'eaten',
#  'totally',
#  'throw',
#  'mine',
#  'waste',
#  'stay',
#  'granola',
#  'night',
#  'pound',
#  'delivered',
#  'pepper',
#  'fish',
#  'lower',
#  'mountain',
#  'cheap',
#  'mind',
#  'gum',
#  'hours',
#  'experience',
#  'finding',
#  'almonds',
#  'delivery',
#  'bite',
#  'service',
#  'convenient',
#  'pure',
#  'packets',
#  'pot',
#  'decent',
#  'loose',
#  'noodles',
#  'vitamin',
#  'market',
#  'soda',
#  'easier',
#  'tiny',
#  'puppy',
#  'supposed',
#  'pop',
#  'worked',
#  'call',
#  'thinking',
#  'packet',
#  'baked',
#  'liquid',
#  'true',
#  'turned',
#  'packed',
#  'wrong',
#  'items',
#  'hand',
#  'label',
#  'bean',
#  'flour',
#  'seeds',
#  'flavorful',
#  'set',
#  'stock',
#  'point',
#  'customer',
#  'sell',
#  'bring',
#  'higher',
#  'pick',
#  'brewed',
#  'course',
#  'hoping',
#  'serve',
#  'mint',
#  'blood',
#  'check',
#  'wet',
#  'thick',
#  'sort',
#  'double',
#  'notice',
#  'weak',
#  'remember',
#  'feeling',
#  'individual',
#  'plan',
#  'including',
#  'stash',
#  'piece',
#  'addition',
#  'fairly',
#  'nut']

# %%
# K-Means

kmeans = MiniBatchKMeans(n_clusters=10, random_state = 0).fit(normalize(vec))

# From each centroid, select the top 5 words that represent the centroid

output_words, feature_values = [], []
sortingCenter = kmeans.cluster_centers_.argsort()[:,::-1]

for i in range(len(sortingCenter)):
  word_list = []
  feature_List = []
  for word in list(sortingCenter[i, :5]):
    word_list.append(top_500_words[word])
    feature_List.append(kmeans.cluster_centers_[i, word])
  output_words.append(word_list)
  feature_values.append(feature_List)

# %%
# Display the top 5 words that represent the centroid

for i in range(0,10):
  print("\nCluster " +str(i+1)+ ":")
  print("Word List:", output_words[i]) 
  print("Feature Values:", feature_values[i])
# Out:
# Cluster 1:
# Word List: ['dog', 'treats', 'dogs', 'loves', 'treat']
# Feature Values: [0.3625607220808383, 0.1711261115644266, 0.11148634211935403, 0.09853883927518238, 0.08082640804802005]
#
# Cluster 2:
# Word List: ['amazon', 'find', 'product', 'price', 'love']
# Feature Values: [0.29778634268259774, 0.07557348729366777, 0.07053053203413101, 0.0693976662908947, 0.05200028908801511]
#
# Cluster 3:
# Word List: ['food', 'cat', 'cats', 'eat', 'dog']
# Feature Values: [0.4221378500538321, 0.11956680069265775, 0.080429065535092, 0.0687086830360354, 0.06603196068516683]
#
# Cluster 4:
# Word List: ['tea', 'flavor', 'taste', 'good', 'green']
# Feature Values: [0.547064304203827, 0.06709559478156352, 0.0666658378114378, 0.06159740960833416, 0.06023932606306848]
#
# Cluster 5:
# Word List: ['coffee', 'cup', 'flavor', 'good', 'taste']
# Feature Values: [0.4944227063929971, 0.10578325086323535, 0.07649579911387093, 0.07069847102990541, 0.06697151057541496]
#
# Cluster 6:
# Word List: ['product', 'great', 'good', 'will', 'taste']
# Feature Values: [0.3878398810118747, 0.06327832601452131, 0.059308412342830685, 0.05240187896688404, 0.04155069050902757]
#
# Cluster 7:
# Word List: ['great', 'love', 'taste', 'flavor', 'price']
# Feature Values: [0.3678490008614635, 0.07565436003042454, 0.07023553148732124, 0.05457375182079384, 0.03963176776155207]
#
# Cluster 8:
# Word List: ['taste', 'love', 'flavor', 'will', 'best']
# Feature Values: [0.06485491829080803, 0.05579490339855662, 0.054471551705924846, 0.0479703602068003, 0.03729142950734002]
#
# Cluster 9:
# Word List: ['sweet', 'taste', 'flavor', 'good', 'sugar']
# Feature Values: [0.2863161888480967, 0.1018336988353514, 0.08430954780866098, 0.06206423237854324, 0.05645234366624956]
#
# Cluster 10:
# Word List: ['good', 'taste', 'flavor', 'great', 'will']
# Feature Values: [0.3558624066517959, 0.08645689414418117, 0.060834922442845704, 0.04463814864931646, 0.03763701484004812]
